# %%
# the Python Requests package will allow us to send HTTP requests to get HTML files
import requests

# the GET method indicates that you’re trying to get or retrieve data from a specified resource. 
# to make a GET request, invoke requests.get()
from requests import get

# Beautiful Soup is a Python library for pulling data out of HTML and XML files
from bs4 import BeautifulSoup

# pandas is a Python data analysis library
import pandas as pd

# NumPy is a Python library used for working with large, multi-dimensional arrays and matrices
import numpy as np

# Datetime is a module that supplies classes for manipulating dates and times
from datetime import datetime

# The os module provides a portable way of using operating system dependent functionality
import os

# The os.path module implements some useful functions on pathnames
import os.path as path

# %%
# look in working directory for CSV file where existing data is stored and read as dataframe
# if this file does not exist, create empty dataframe with columns corresponding to required information
if path.exists('cheebas.csv'):
   existing_data = pd.read_csv('cheebas.csv')
else:
   columns = ['date', 'product', 'category', 'price']
   existing_data = pd.DataFrame(columns = columns)

# %%
existing_data
# Out:
#           date                                      product  \
# 0   2022-03-15            Death Bubba Hash by Tegridy Farms
# 1   2022-03-15            Master Kush Hash by Tegridy Farms
# 2   2022-03-15           Gorilla Glue Hash By Tegridy Farms
# 3   2022-03-15                     Tuna Rockstar HASH by TF
# 4   2022-03-15           Chernobyl Cookies by Tegridy Farms
# 5   2022-03-15                   Malani Style Elephant Hash
# 6   2022-03-15            Gods Green Crack by Tegridy Farms
# 7   2022-03-15                        Dragon Full Melt Hash
# 8   2022-03-15                   Tegridy Farms - Hindu Kush
# 9   2022-03-15                  Blue Dream by Tegridy Farms
# 10  2022-03-15                  Lebanese Style Rooster Hash
# 11  2022-03-15               MK Ultra Hash by Tegridy Farms
# 12  2022-03-15               Phoenix Stamp Banana Kush Hash
# 13  2022-03-15               Pink Goo Hash by Tegridy Farms
# 14  2022-03-15                     Kush Mint Full Melt Hash
# 15  2022-03-15  Sophies Breath Sativa Hash by Tegridy Farms
# 16  2022-03-15                            Healing Tree Hash
# 17  2022-03-15                                   Mayan Gold
# 18  2022-03-15            Gelato x Do-si-Dos Full Melt Hash
# 19  2022-03-15             Holy Bible Stamp Lindsay OG Hash
# 20  2022-03-15                          Dove Stamp MK Ultra
# 21  2022-03-15               Sugar Cookies by Tegridy Farms
# 22  2022-03-15   20g Island Bushido Chunk by Hash Assassins
# 23  2022-03-15                               Citrus Cookies
# 24  2022-03-15                               Triangle Mints
# 25  2022-03-15               Orange Aid 7g by Tegridy Farms
# 26  2022-04-14            Master Kush Hash by Tegridy Farms
# 27  2022-04-14          Tuna Rockstar HASH by Tegridy Farms
# 28  2022-04-14                   Tegridy Farms - Hindu Kush
# 29  2022-04-14               Pink Goo Hash by Tegridy Farms
# 30  2022-04-14           Chernobyl Cookies by Tegridy Farms
# 31  2022-04-14           Gorilla Glue Hash By Tegridy Farms
# 32  2022-04-14                                  Kings Crown
# 33  2022-04-14         Full Melt Hash Banana Cookies Strain
# 34  2022-04-14                 Death Star by Hash Assassins
# 35  2022-04-14                     Kush Mint Full Melt Hash
# 36  2022-04-14                      Tom Ford Full Melt Hash
# 37  2022-04-14                   Malani Style Elephant Hash
# 38  2022-04-14               MK Ultra Hash by Tegridy Farms
# 39  2022-04-14                    Full Melt Wildberry Runtz
# 40  2022-04-14               Phoenix Stamp Banana Kush Hash
# 41  2022-04-14     Sour Dream Sativa Hash by Hash Assassins
# 42  2022-04-14            Gods Green Crack by Tegridy Farms
# 43  2022-04-14            Death Bubba Hash by Tegridy Farms
# 44  2022-04-14             Holy Bible Stamp Lindsay OG Hash
# 45  2022-04-14                   GDP Fresh Frozen Full Melt
# 46  2022-04-14                                   Mayan Gold
# 47  2022-04-14                               Triangle Mints
# 48  2022-04-14                7g Gelato 33 by Tegridy Farms
# 49  2022-04-14                               Mad Scientist
# 50  2022-04-14                                  Five Alive
# 51  2022-04-14               Orange Aid 7g by Tegridy Farms
# 52  2022-04-14                                       Mimosa
# 53  2022-04-14                              Mandarin Sunset
# 54  2022-04-14                                      Orange
#
#                  category     price
# 0   premium-domestic-hash  $16.00/g
# 1   premium-domestic-hash  $15.00/g
# 2   premium-domestic-hash  $16.00/g
# 3   premium-domestic-hash  $16.00/g
# 4   premium-domestic-hash  $16.00/g
# 5   premium-domestic-hash  $13.00/g
# 6   premium-domestic-hash  $17.00/g
# 7   premium-domestic-hash  $18.00/g
# 8   premium-domestic-hash  $14.00/g
# 9   premium-domestic-hash  $16.50/g
# 10  premium-domestic-hash  $12.00/g
# 11  premium-domestic-hash  $15.00/g
# 12  premium-domestic-hash  $15.50/g
# 13  premium-domestic-hash  $15.00/g
# 14  premium-domestic-hash  $18.00/g
# 15  premium-domestic-hash  $16.00/g
# 16  premium-domestic-hash  $12.00/g
# 17  premium-domestic-hash  $14.00/g
# 18  premium-domestic-hash  $18.00/g
# 19  premium-domestic-hash  $17.00/g
# 20  premium-domestic-hash  $17.00/g
# 21  premium-domestic-hash  $17.00/g
# 22  premium-domestic-hash  $230.00
# 23      buy-sativa-online   $4.00/g
# 24      buy-sativa-online   $5.00/g
# 25      buy-sativa-online   $78.50
# 26  premium-domestic-hash  $15.00/g
# 27  premium-domestic-hash  $15.00/g
# 28  premium-domestic-hash  $14.00/g
# 29  premium-domestic-hash  $15.00/g
# 30  premium-domestic-hash  $14.00/g
# 31  premium-domestic-hash  $16.00/g
# 32  premium-domestic-hash  $19.00/g
# 33  premium-domestic-hash  $17.00/g
# 34  premium-domestic-hash  $15.00/g
# 35  premium-domestic-hash  $18.00/g
# 36  premium-domestic-hash  $17.00/g
# 37  premium-domestic-hash  $13.00/g
# 38  premium-domestic-hash  $14.00/g
# 39  premium-domestic-hash  $17.00/g
# 40  premium-domestic-hash  $13.00/g
# 41  premium-domestic-hash  $15.00/g
# 42  premium-domestic-hash  $15.00/g
# 43  premium-domestic-hash  $15.50/g
# 44  premium-domestic-hash  $14.00/g
# 45  premium-domestic-hash  $19.00/g
# 46  premium-domestic-hash  $18.00/g
# 47      buy-sativa-online   $5.00/g
# 48      buy-sativa-online   $69.00
# 49      buy-sativa-online   $5.75/g
# 50      buy-sativa-online   $6.50/g
# 51      buy-sativa-online   $69.00
# 52      buy-sativa-online   $6.75/g
# 53      buy-sativa-online   $8.25/g
# 54      buy-sativa-online   $8.00/g

# %% [markdown]
# To find new data, this script can be run and cannabis prices can be found for a particular date

# %%
# the URLs we want to obtain data from
url = 'https://www.cheebas.co/'
keys = ['premium-domestic-hash', 'buy-sativa-online']

# store scraped data in lists
all_names = []
all_prices = []
all_categories = []
date = []

# iterate through each URL
for key in keys:
    results = requests.get(url + key)
    
    # parse web content into Python-readable format
    soup = BeautifulSoup(results.content, "html.parser")
    
    # from inspecting the HTML, information we need is stored here for each product
    # the find_all() function will find every instance of matching tags and filters from the soup
    products = soup.find_all('div', class_="product-thumb")
    
    # iterate through each product and obtain data from each
    for product in products:
        # obtain where the name of each product is stored
        product_link = product.find('a')
        name = product_link.get('title')
        
        # obtain where the price per unit of each product is stored
        price_per_quantity = product.find('h4', class_='thumb-price').find('b').text
        
        # obtain the date the script is being run
        current_date = datetime.today().strftime('%Y-%m-%d')

        # add data to lists
        all_names.append(name)
        all_prices.append(price_per_quantity)
        all_categories.append(key)
        date.append(current_date)

        print(name)
        print(price_per_quantity)
        print(current_date)
# Out:
# Master Kush Hash by Tegridy Farms
# $15.00/g
# 2022-04-14
# Tuna Rockstar HASH by Tegridy Farms
# $15.00/g
# 2022-04-14
# Tegridy Farms - Hindu Kush
# $14.00/g
# 2022-04-14
# Pink Goo Hash by Tegridy Farms
# $15.00/g
# 2022-04-14
# Chernobyl Cookies by Tegridy Farms
# $14.00/g
# 2022-04-14
# Gorilla Glue Hash By Tegridy Farms
# $16.00/g
# 2022-04-14
# Kings Crown
# $19.00/g
# 2022-04-14
# Full Melt Hash Banana Cookies Strain
# $17.00/g
# 2022-04-14
# Death Star by Hash Assassins
# $15.00/g
# 2022-04-14
# Kush Mint Full Melt Hash
# $18.00/g
# 2022-04-14
# Tom Ford Full Melt Hash
# $17.00/g
# 2022-04-14
# Malani Style Elephant Hash
# $13.00/g
# 2022-04-14
# MK Ultra Hash by Tegridy Farms
# $14.00/g
# 2022-04-14
# Full Melt Wildberry Runtz
# $17.00/g
# 2022-04-14
# Phoenix Stamp Banana Kush Hash
# $13.00/g
# 2022-04-14
# Sour Dream Sativa Hash by Hash Assassins
# $15.00/g
# 2022-04-14
# Gods Green Crack by Tegridy Farms
# $15.00/g
# 2022-04-14
# Death Bubba Hash by Tegridy Farms
# $15.50/g
# 2022-04-14
# Holy Bible Stamp Lindsay OG Hash
# $14.00/g
# 2022-04-14
# GDP Fresh Frozen Full Melt
# $19.00/g
# 2022-04-14
# Mayan Gold
# $18.00/g
# 2022-04-14
# Triangle Mints
# $5.00/g
# 2022-04-14
# 7g Gelato 33 by Tegridy Farms
# $69.00
# 2022-04-14
# Mad Scientist
# $5.75/g
# 2022-04-14
# Five Alive
# $6.50/g
# 2022-04-14
# Orange Aid 7g by Tegridy Farms
# $69.00
# 2022-04-14
# Mimosa
# $6.75/g
# 2022-04-14
# Mandarin Sunset
# $8.25/g
# 2022-04-14
# Orange
# $8.00/g
# 2022-04-14

# %%
# create dataframe using new data
new_data = pd.DataFrame(
    {'date': date,
     'product': all_names,
     'category': all_categories,
     'price': all_prices,
    })

# %%
new_data
# Out:
#           date                                   product  \
# 0   2022-04-14         Master Kush Hash by Tegridy Farms
# 1   2022-04-14       Tuna Rockstar HASH by Tegridy Farms
# 2   2022-04-14                Tegridy Farms - Hindu Kush
# 3   2022-04-14            Pink Goo Hash by Tegridy Farms
# 4   2022-04-14        Chernobyl Cookies by Tegridy Farms
# 5   2022-04-14        Gorilla Glue Hash By Tegridy Farms
# 6   2022-04-14                               Kings Crown
# 7   2022-04-14      Full Melt Hash Banana Cookies Strain
# 8   2022-04-14              Death Star by Hash Assassins
# 9   2022-04-14                  Kush Mint Full Melt Hash
# 10  2022-04-14                   Tom Ford Full Melt Hash
# 11  2022-04-14                Malani Style Elephant Hash
# 12  2022-04-14            MK Ultra Hash by Tegridy Farms
# 13  2022-04-14                 Full Melt Wildberry Runtz
# 14  2022-04-14            Phoenix Stamp Banana Kush Hash
# 15  2022-04-14  Sour Dream Sativa Hash by Hash Assassins
# 16  2022-04-14         Gods Green Crack by Tegridy Farms
# 17  2022-04-14         Death Bubba Hash by Tegridy Farms
# 18  2022-04-14          Holy Bible Stamp Lindsay OG Hash
# 19  2022-04-14                GDP Fresh Frozen Full Melt
# 20  2022-04-14                                Mayan Gold
# 21  2022-04-14                            Triangle Mints
# 22  2022-04-14             7g Gelato 33 by Tegridy Farms
# 23  2022-04-14                            Mad Scientist
# 24  2022-04-14                               Five Alive
# 25  2022-04-14            Orange Aid 7g by Tegridy Farms
# 26  2022-04-14                                    Mimosa
# 27  2022-04-14                           Mandarin Sunset
# 28  2022-04-14                                   Orange
#
#                  category     price
# 0   premium-domestic-hash  $15.00/g
# 1   premium-domestic-hash  $15.00/g
# 2   premium-domestic-hash  $14.00/g
# 3   premium-domestic-hash  $15.00/g
# 4   premium-domestic-hash  $14.00/g
# 5   premium-domestic-hash  $16.00/g
# 6   premium-domestic-hash  $19.00/g
# 7   premium-domestic-hash  $17.00/g
# 8   premium-domestic-hash  $15.00/g
# 9   premium-domestic-hash  $18.00/g
# 10  premium-domestic-hash  $17.00/g
# 11  premium-domestic-hash  $13.00/g
# 12  premium-domestic-hash  $14.00/g
# 13  premium-domestic-hash  $17.00/g
# 14  premium-domestic-hash  $13.00/g
# 15  premium-domestic-hash  $15.00/g
# 16  premium-domestic-hash  $15.00/g
# 17  premium-domestic-hash  $15.50/g
# 18  premium-domestic-hash  $14.00/g
# 19  premium-domestic-hash  $19.00/g
# 20  premium-domestic-hash  $18.00/g
# 21      buy-sativa-online   $5.00/g
# 22      buy-sativa-online    $69.00
# 23      buy-sativa-online   $5.75/g
# 24      buy-sativa-online   $6.50/g
# 25      buy-sativa-online    $69.00
# 26      buy-sativa-online   $6.75/g
# 27      buy-sativa-online   $8.25/g
# 28      buy-sativa-online   $8.00/g

# %%
# join original and new data by column
joined_data = pd.concat([existing_data, new_data])

# %%
joined_data
# Out:
#           date                             product               category  \
# 0   2022-03-15   Death Bubba Hash by Tegridy Farms  premium-domestic-hash
# 1   2022-03-15   Master Kush Hash by Tegridy Farms  premium-domestic-hash
# 2   2022-03-15  Gorilla Glue Hash By Tegridy Farms  premium-domestic-hash
# 3   2022-03-15            Tuna Rockstar HASH by TF  premium-domestic-hash
# 4   2022-03-15  Chernobyl Cookies by Tegridy Farms  premium-domestic-hash
# ..         ...                                 ...                    ...
# 24  2022-04-14                         Five Alive       buy-sativa-online
# 25  2022-04-14      Orange Aid 7g by Tegridy Farms      buy-sativa-online
# 26  2022-04-14                              Mimosa      buy-sativa-online
# 27  2022-04-14                     Mandarin Sunset      buy-sativa-online
# 28  2022-04-14                             Orange       buy-sativa-online
#
#        price
# 0   $16.00/g
# 1   $15.00/g
# 2   $16.00/g
# 3   $16.00/g
# 4   $16.00/g
# ..       ...
# 24   $6.50/g
# 25    $69.00
# 26   $6.75/g
# 27   $8.25/g
# 28   $8.00/g
#
# [84 rows x 4 columns]

# %%
# ensure duplicates are removed in case data is added twice
final_data = joined_data.drop_duplicates(subset=['date', 'product'], keep = 'last', inplace=False)

# %%
final_data
# Out:
#           date                                      product  \
# 0   2022-03-15            Death Bubba Hash by Tegridy Farms
# 1   2022-03-15            Master Kush Hash by Tegridy Farms
# 2   2022-03-15           Gorilla Glue Hash By Tegridy Farms
# 3   2022-03-15                     Tuna Rockstar HASH by TF
# 4   2022-03-15           Chernobyl Cookies by Tegridy Farms
# 5   2022-03-15                   Malani Style Elephant Hash
# 6   2022-03-15            Gods Green Crack by Tegridy Farms
# 7   2022-03-15                        Dragon Full Melt Hash
# 8   2022-03-15                   Tegridy Farms - Hindu Kush
# 9   2022-03-15                  Blue Dream by Tegridy Farms
# 10  2022-03-15                  Lebanese Style Rooster Hash
# 11  2022-03-15               MK Ultra Hash by Tegridy Farms
# 12  2022-03-15               Phoenix Stamp Banana Kush Hash
# 13  2022-03-15               Pink Goo Hash by Tegridy Farms
# 14  2022-03-15                     Kush Mint Full Melt Hash
# 15  2022-03-15  Sophies Breath Sativa Hash by Tegridy Farms
# 16  2022-03-15                            Healing Tree Hash
# 17  2022-03-15                                   Mayan Gold
# 18  2022-03-15            Gelato x Do-si-Dos Full Melt Hash
# 19  2022-03-15             Holy Bible Stamp Lindsay OG Hash
# 20  2022-03-15                          Dove Stamp MK Ultra
# 21  2022-03-15               Sugar Cookies by Tegridy Farms
# 22  2022-03-15   20g Island Bushido Chunk by Hash Assassins
# 23  2022-03-15                               Citrus Cookies
# 24  2022-03-15                               Triangle Mints
# 25  2022-03-15               Orange Aid 7g by Tegridy Farms
# 0   2022-04-14            Master Kush Hash by Tegridy Farms
# 1   2022-04-14          Tuna Rockstar HASH by Tegridy Farms
# 2   2022-04-14                   Tegridy Farms - Hindu Kush
# 3   2022-04-14               Pink Goo Hash by Tegridy Farms
# 4   2022-04-14           Chernobyl Cookies by Tegridy Farms
# 5   2022-04-14           Gorilla Glue Hash By Tegridy Farms
# 6   2022-04-14                                  Kings Crown
# 7   2022-04-14         Full Melt Hash Banana Cookies Strain
# 8   2022-04-14                 Death Star by Hash Assassins
# 9   2022-04-14                     Kush Mint Full Melt Hash
# 10  2022-04-14                      Tom Ford Full Melt Hash
# 11  2022-04-14                   Malani Style Elephant Hash
# 12  2022-04-14               MK Ultra Hash by Tegridy Farms
# 13  2022-04-14                    Full Melt Wildberry Runtz
# 14  2022-04-14               Phoenix Stamp Banana Kush Hash
# 15  2022-04-14     Sour Dream Sativa Hash by Hash Assassins
# 16  2022-04-14            Gods Green Crack by Tegridy Farms
# 17  2022-04-14            Death Bubba Hash by Tegridy Farms
# 18  2022-04-14             Holy Bible Stamp Lindsay OG Hash
# 19  2022-04-14                   GDP Fresh Frozen Full Melt
# 20  2022-04-14                                   Mayan Gold
# 21  2022-04-14                               Triangle Mints
# 22  2022-04-14                7g Gelato 33 by Tegridy Farms
# 23  2022-04-14                               Mad Scientist
# 24  2022-04-14                                  Five Alive
# 25  2022-04-14               Orange Aid 7g by Tegridy Farms
# 26  2022-04-14                                       Mimosa
# 27  2022-04-14                              Mandarin Sunset
# 28  2022-04-14                                      Orange
#
#                  category     price
# 0   premium-domestic-hash  $16.00/g
# 1   premium-domestic-hash  $15.00/g
# 2   premium-domestic-hash  $16.00/g
# 3   premium-domestic-hash  $16.00/g
# 4   premium-domestic-hash  $16.00/g
# 5   premium-domestic-hash  $13.00/g
# 6   premium-domestic-hash  $17.00/g
# 7   premium-domestic-hash  $18.00/g
# 8   premium-domestic-hash  $14.00/g
# 9   premium-domestic-hash  $16.50/g
# 10  premium-domestic-hash  $12.00/g
# 11  premium-domestic-hash  $15.00/g
# 12  premium-domestic-hash  $15.50/g
# 13  premium-domestic-hash  $15.00/g
# 14  premium-domestic-hash  $18.00/g
# 15  premium-domestic-hash  $16.00/g
# 16  premium-domestic-hash  $12.00/g
# 17  premium-domestic-hash  $14.00/g
# 18  premium-domestic-hash  $18.00/g
# 19  premium-domestic-hash  $17.00/g
# 20  premium-domestic-hash  $17.00/g
# 21  premium-domestic-hash  $17.00/g
# 22  premium-domestic-hash  $230.00
# 23      buy-sativa-online   $4.00/g
# 24      buy-sativa-online   $5.00/g
# 25      buy-sativa-online   $78.50
# 0   premium-domestic-hash  $15.00/g
# 1   premium-domestic-hash  $15.00/g
# 2   premium-domestic-hash  $14.00/g
# 3   premium-domestic-hash  $15.00/g
# 4   premium-domestic-hash  $14.00/g
# 5   premium-domestic-hash  $16.00/g
# 6   premium-domestic-hash  $19.00/g
# 7   premium-domestic-hash  $17.00/g
# 8   premium-domestic-hash  $15.00/g
# 9   premium-domestic-hash  $18.00/g
# 10  premium-domestic-hash  $17.00/g
# 11  premium-domestic-hash  $13.00/g
# 12  premium-domestic-hash  $14.00/g
# 13  premium-domestic-hash  $17.00/g
# 14  premium-domestic-hash  $13.00/g
# 15  premium-domestic-hash  $15.00/g
# 16  premium-domestic-hash  $15.00/g
# 17  premium-domestic-hash  $15.50/g
# 18  premium-domestic-hash  $14.00/g
# 19  premium-domestic-hash  $19.00/g
# 20  premium-domestic-hash  $18.00/g
# 21      buy-sativa-online   $5.00/g
# 22      buy-sativa-online    $69.00
# 23      buy-sativa-online   $5.75/g
# 24      buy-sativa-online   $6.50/g
# 25      buy-sativa-online    $69.00
# 26      buy-sativa-online   $6.75/g
# 27      buy-sativa-online   $8.25/g
# 28      buy-sativa-online   $8.00/g

# %%
# define filename for data
output_path = 'cheebas.csv'

# overwrite previous file with new file containing previous and new data
joined_data.to_csv(output_path, index = False)
