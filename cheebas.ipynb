# %%
# the Python Requests package will allow us to send HTTP requests to get HTML files
import requests

# the GET method indicates that you’re trying to get or retrieve data from a specified resource. 
# to make a GET request, invoke requests.get()
from requests import get

# Beautiful Soup is a Python library for pulling data out of HTML and XML files
from bs4 import BeautifulSoup

# pandas is a Python data analysis library
import pandas as pd

# NumPy is a Python library used for working with large, multi-dimensional arrays and matrices
import numpy as np

from datetime import datetime

# %%
url = 'https://www.cheebas.co/'

keys = ['premium-domestic-hash', 'buy-sativa-online']

all_names = []

all_prices = []

date = []

for key in keys:
    results = requests.get(url + key)

    soup = BeautifulSoup(results.content, "html.parser")

    products = soup.find_all('div', class_="product-thumb")

    for product in products:
        product_link = product.find('a')
        name = product_link.get('title')
        product_page = product_link.get('href')
        
        price_per_quantity = product.find('h4', class_='thumb-price').find('b').text
        
        current_month = datetime.now().month
        current_year = datetime.now().year

        all_names.append(name)
        all_prices.append(price_per_quantity)
        date.append(str(current_month) + '/' + str(current_year))
        
        print(name)
        print(price_per_quantity)
# Out:
# Master Kush Hash by Tegridy Farms
# $15.00/g
# Blue Dream by Tegridy Farms
# $16.50/g
# Chernobyl Cookies by Tegridy Farms
# $16.00/g
# Dragon Full Melt Hash
# $18.00/g
# Gorilla Glue Hash By Tegridy Farms
# $16.00/g
# Kush Mint Full Melt Hash
# $18.00/g
# Sophies Breath Sativa Hash by Tegridy Farms
# $16.00/g
# Malani Style Elephant Hash
# $13.00/g
# Healing Tree Hash
# $12.00/g
# Phoenix Stamp Banana Kush Hash
# $15.50/g
# Tuna Rockstar HASH by TF
# $16.00/g
# Gelato x Do-si-Dos Full Melt Hash
# $18.00/g
# Death Bubba Hash by Tegridy Farms
# $17.00/g
# Pink Goo Hash by Tegridy Farms
# $15.00/g
# Gods Green Crack by Tegridy Farms
# $17.00/g
# Mayan Gold
# $14.00/g
# Holy Bible Stamp Lindsay OG Hash
# $17.00/g
# Dove Stamp MK Ultra
# $17.00/g
# Sugar Cookies by Tegridy Farms
# $17.00/g
# Lebanese Style Rooster Hash
# $12.00/g
# 20g Island Bushido Chunk by Hash Assassins
# $230.00
# Chiesel
# $5.75/g
# Citrique
# $4.00/g
# Triangle Mints
# $5.50/g
# Mimosa
# $4.00/g
# Orange Aid 7g by Tegridy Farms
# $78.50
# Sour Diesel
# $5.00/g
# Tangerine Dream 7g Herban Legands
# $76.00
# Congo Guava 7g Sativa by Tegridy Farms
# $78.50

# %%
df = pd.DataFrame(
    {'Date': date,
     'Product': all_names,
     'Price': all_prices,
    })

# %%
df
# Out:
#       Date                                      Product     Price
# 0   2/2022            Master Kush Hash by Tegridy Farms  $15.00/g
# 1   2/2022                  Blue Dream by Tegridy Farms  $16.50/g
# 2   2/2022           Chernobyl Cookies by Tegridy Farms  $16.00/g
# 3   2/2022                        Dragon Full Melt Hash  $18.00/g
# 4   2/2022           Gorilla Glue Hash By Tegridy Farms  $16.00/g
# 5   2/2022                     Kush Mint Full Melt Hash  $18.00/g
# 6   2/2022  Sophies Breath Sativa Hash by Tegridy Farms  $16.00/g
# 7   2/2022                   Malani Style Elephant Hash  $13.00/g
# 8   2/2022                            Healing Tree Hash  $12.00/g
# 9   2/2022               Phoenix Stamp Banana Kush Hash  $15.50/g
# 10  2/2022                     Tuna Rockstar HASH by TF  $16.00/g
# 11  2/2022            Gelato x Do-si-Dos Full Melt Hash  $18.00/g
# 12  2/2022            Death Bubba Hash by Tegridy Farms  $17.00/g
# 13  2/2022               Pink Goo Hash by Tegridy Farms  $15.00/g
# 14  2/2022            Gods Green Crack by Tegridy Farms  $17.00/g
# 15  2/2022                                   Mayan Gold  $14.00/g
# 16  2/2022             Holy Bible Stamp Lindsay OG Hash  $17.00/g
# 17  2/2022                          Dove Stamp MK Ultra  $17.00/g
# 18  2/2022               Sugar Cookies by Tegridy Farms  $17.00/g
# 19  2/2022                  Lebanese Style Rooster Hash  $12.00/g
# 20  2/2022   20g Island Bushido Chunk by Hash Assassins   $230.00
# 21  2/2022                                      Chiesel   $5.75/g
# 22  2/2022                                     Citrique   $4.00/g
# 23  2/2022                               Triangle Mints   $5.50/g
# 24  2/2022                                       Mimosa   $4.00/g
# 25  2/2022               Orange Aid 7g by Tegridy Farms    $78.50
# 26  2/2022                                  Sour Diesel   $5.00/g
# 27  2/2022           Tangerine Dream 7g Herban Legands     $76.00
# 28  2/2022       Congo Guava 7g Sativa by Tegridy Farms    $78.50

# %%
df.to_csv('cheebas.csv')
