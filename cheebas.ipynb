# %%
# the Python Requests package will allow us to send HTTP requests to get HTML files
import requests

# the GET method indicates that you’re trying to get or retrieve data from a specified resource. 
# to make a GET request, invoke requests.get()
from requests import get

# Beautiful Soup is a Python library for pulling data out of HTML and XML files
from bs4 import BeautifulSoup

# pandas is a Python data analysis library
import pandas as pd

# NumPy is a Python library used for working with large, multi-dimensional arrays and matrices
import numpy as np

# Datetime is a module that supplies classes for manipulating dates and times
from datetime import datetime

# The os module provides a portable way of using operating system dependent functionality
import os

# The os.path module implements some useful functions on pathnames
import os.path as path

# %%
# look in working directory for CSV file where existing data is stored and read as dataframe
# if this file does not exist, create empty dataframe with columns corresponding to required information
if path.exists('cheebas.csv'):
   existing_data = pd.read_csv('cheebas.csv')
else:
   columns = ['date', 'product', 'category', 'price']
   existing_data = pd.DataFrame(columns = columns)

# %%
existing_data
# Out:
#           date                             product               category  \
# 0   2022-03-15   Death Bubba Hash by Tegridy Farms  premium-domestic-hash
# 1   2022-03-15   Master Kush Hash by Tegridy Farms  premium-domestic-hash
# 2   2022-03-15  Gorilla Glue Hash By Tegridy Farms  premium-domestic-hash
# 3   2022-03-15            Tuna Rockstar HASH by TF  premium-domestic-hash
# 4   2022-03-15  Chernobyl Cookies by Tegridy Farms  premium-domestic-hash
# ..         ...                                 ...                    ...
# 79  2022-04-14                         Five Alive       buy-sativa-online
# 80  2022-04-14      Orange Aid 7g by Tegridy Farms      buy-sativa-online
# 81  2022-04-14                              Mimosa      buy-sativa-online
# 82  2022-04-14                     Mandarin Sunset      buy-sativa-online
# 83  2022-04-14                             Orange       buy-sativa-online
#
#        price
# 0   $16.00/g
# 1   $15.00/g
# 2   $16.00/g
# 3   $16.00/g
# 4   $16.00/g
# ..       ...
# 79   $6.50/g
# 80    $69.00
# 81   $6.75/g
# 82   $8.25/g
# 83   $8.00/g
#
# [84 rows x 4 columns]

# %% [markdown]
# To find new data, this script can be run and cannabis prices can be found for a particular date

# %%
# the URLs we want to obtain data from
url = 'https://www.cheebas.co/'
keys = ['premium-domestic-hash', 'buy-sativa-online']

# store scraped data in lists
all_names = []
all_prices = []
all_categories = []
date = []

# iterate through each URL
for key in keys:
    results = requests.get(url + key)
    
    # parse web content into Python-readable format
    soup = BeautifulSoup(results.content, "html.parser")
    
    # from inspecting the HTML, information we need is stored here for each product
    # the find_all() function will find every instance of matching tags and filters from the soup
    products = soup.find_all('div', class_="product-thumb")
    
    # iterate through each product and obtain data from each
    for product in products:
        # obtain where the name of each product is stored
        product_link = product.find('a')
        name = product_link.get('title')
        
        # obtain where the price per unit of each product is stored
        price_per_quantity = product.find('h4', class_='thumb-price').find('b').text
        
        # obtain the date the script is being run
        current_date = datetime.today().strftime('%Y-%m-%d')

        # add data to lists
        all_names.append(name)
        all_prices.append(price_per_quantity)
        all_categories.append(key)
        date.append(current_date)

        print(name)
        print(price_per_quantity)
        print(current_date)
# Out:
# Master Kush Hash by Tegridy Farms
# $15.00/g
# 2022-05-09
# MK Ultra Hash by Tegridy Farms
# $14.00/g
# 2022-05-09
# Tuna Rockstar HASH by Tegridy Farms
# $15.00/g
# 2022-05-09
# Tegridy Farms - Hindu Kush
# $14.00/g
# 2022-05-09
# Pink Goo Hash by Tegridy Farms
# $15.00/g
# 2022-05-09
# Malani Style Elephant Hash
# $8.45/g
# 2022-05-09
# Gorilla Glue Hash By Tegridy Farms
# $16.00/g
# 2022-05-09
# Slurry Crashers Full Melt
# $17.00/g
# 2022-05-09
# Full Melt Runtz
# $17.00/g
# 2022-05-09
# Death Bubba Hash by Tegridy Farms
# $14.00/g
# 2022-05-09
# Chernobyl Cookies by Tegridy Farms
# $14.00/g
# 2022-05-09
# Cereal Milk Full Melt
# $17.00/g
# 2022-05-09
# Sour Dream Sativa Hash by Hash Assassins
# $15.00/g
# 2022-05-09
# Kush Mint Full Melt Hash
# $18.00/g
# 2022-05-09
# Death Star by Hash Assassins
# $15.00/g
# 2022-05-09
# Full Melt Hash Banana Cookies Strain
# $17.00/g
# 2022-05-09
# Cured Finger Rub
# $19.00/g
# 2022-05-09
# Phoenix Stamp Banana Kush Hash
# $10.00/g
# 2022-05-09
# Tom Ford Full Melt Hash
# $13.81/g
# 2022-05-09
# Pink Gas Zero Zero 7g Egg
# $99.00
# 2022-05-09
# Kings Crown
# $19.50/g
# 2022-05-09
# Chiesel
# $5.75/g
# 2022-05-09
# Triangle Mints
# $5.00/g
# 2022-05-09
# 7g Gelato 33 by Herban Legends
# $69.00
# 2022-05-09

# %%
# create dataframe using new data
new_data = pd.DataFrame(
    {'date': date,
     'product': all_names,
     'category': all_categories,
     'price': all_prices,
    })

# %%
new_data
# Out:
#           date                                   product  \
# 0   2022-05-09         Master Kush Hash by Tegridy Farms
# 1   2022-05-09            MK Ultra Hash by Tegridy Farms
# 2   2022-05-09       Tuna Rockstar HASH by Tegridy Farms
# 3   2022-05-09                Tegridy Farms - Hindu Kush
# 4   2022-05-09            Pink Goo Hash by Tegridy Farms
# 5   2022-05-09                Malani Style Elephant Hash
# 6   2022-05-09        Gorilla Glue Hash By Tegridy Farms
# 7   2022-05-09                 Slurry Crashers Full Melt
# 8   2022-05-09                           Full Melt Runtz
# 9   2022-05-09         Death Bubba Hash by Tegridy Farms
# 10  2022-05-09        Chernobyl Cookies by Tegridy Farms
# 11  2022-05-09                     Cereal Milk Full Melt
# 12  2022-05-09  Sour Dream Sativa Hash by Hash Assassins
# 13  2022-05-09                  Kush Mint Full Melt Hash
# 14  2022-05-09              Death Star by Hash Assassins
# 15  2022-05-09      Full Melt Hash Banana Cookies Strain
# 16  2022-05-09                          Cured Finger Rub
# 17  2022-05-09            Phoenix Stamp Banana Kush Hash
# 18  2022-05-09                   Tom Ford Full Melt Hash
# 19  2022-05-09                 Pink Gas Zero Zero 7g Egg
# 20  2022-05-09                               Kings Crown
# 21  2022-05-09                                   Chiesel
# 22  2022-05-09                            Triangle Mints
# 23  2022-05-09            7g Gelato 33 by Herban Legends
#
#                  category     price
# 0   premium-domestic-hash  $15.00/g
# 1   premium-domestic-hash  $14.00/g
# 2   premium-domestic-hash  $15.00/g
# 3   premium-domestic-hash  $14.00/g
# 4   premium-domestic-hash  $15.00/g
# 5   premium-domestic-hash   $8.45/g
# 6   premium-domestic-hash  $16.00/g
# 7   premium-domestic-hash  $17.00/g
# 8   premium-domestic-hash  $17.00/g
# 9   premium-domestic-hash  $14.00/g
# 10  premium-domestic-hash  $14.00/g
# 11  premium-domestic-hash  $17.00/g
# 12  premium-domestic-hash  $15.00/g
# 13  premium-domestic-hash  $18.00/g
# 14  premium-domestic-hash  $15.00/g
# 15  premium-domestic-hash  $17.00/g
# 16  premium-domestic-hash  $19.00/g
# 17  premium-domestic-hash  $10.00/g
# 18  premium-domestic-hash  $13.81/g
# 19  premium-domestic-hash    $99.00
# 20  premium-domestic-hash  $19.50/g
# 21      buy-sativa-online   $5.75/g
# 22      buy-sativa-online   $5.00/g
# 23      buy-sativa-online    $69.00

# %%
# join original and new data by column
joined_data = pd.concat([existing_data, new_data])

# %%
joined_data
# Out:
#           date                             product               category  \
# 0   2022-03-15   Death Bubba Hash by Tegridy Farms  premium-domestic-hash
# 1   2022-03-15   Master Kush Hash by Tegridy Farms  premium-domestic-hash
# 2   2022-03-15  Gorilla Glue Hash By Tegridy Farms  premium-domestic-hash
# 3   2022-03-15            Tuna Rockstar HASH by TF  premium-domestic-hash
# 4   2022-03-15  Chernobyl Cookies by Tegridy Farms  premium-domestic-hash
# ..         ...                                 ...                    ...
# 19  2022-05-09           Pink Gas Zero Zero 7g Egg  premium-domestic-hash
# 20  2022-05-09                         Kings Crown  premium-domestic-hash
# 21  2022-05-09                             Chiesel      buy-sativa-online
# 22  2022-05-09                      Triangle Mints      buy-sativa-online
# 23  2022-05-09      7g Gelato 33 by Herban Legends      buy-sativa-online
#
#        price
# 0   $16.00/g
# 1   $15.00/g
# 2   $16.00/g
# 3   $16.00/g
# 4   $16.00/g
# ..       ...
# 19    $99.00
# 20  $19.50/g
# 21   $5.75/g
# 22   $5.00/g
# 23    $69.00
#
# [108 rows x 4 columns]

# %%
# ensure duplicates are removed in case data is added twice
final_data = joined_data.drop_duplicates(subset=['date', 'product'], keep = 'last', inplace=False)

# %%
final_data
# Out:
#           date                             product               category  \
# 0   2022-03-15   Death Bubba Hash by Tegridy Farms  premium-domestic-hash
# 1   2022-03-15   Master Kush Hash by Tegridy Farms  premium-domestic-hash
# 2   2022-03-15  Gorilla Glue Hash By Tegridy Farms  premium-domestic-hash
# 3   2022-03-15            Tuna Rockstar HASH by TF  premium-domestic-hash
# 4   2022-03-15  Chernobyl Cookies by Tegridy Farms  premium-domestic-hash
# ..         ...                                 ...                    ...
# 19  2022-05-09           Pink Gas Zero Zero 7g Egg  premium-domestic-hash
# 20  2022-05-09                         Kings Crown  premium-domestic-hash
# 21  2022-05-09                             Chiesel      buy-sativa-online
# 22  2022-05-09                      Triangle Mints      buy-sativa-online
# 23  2022-05-09      7g Gelato 33 by Herban Legends      buy-sativa-online
#
#        price
# 0   $16.00/g
# 1   $15.00/g
# 2   $16.00/g
# 3   $16.00/g
# 4   $16.00/g
# ..       ...
# 19    $99.00
# 20  $19.50/g
# 21   $5.75/g
# 22   $5.00/g
# 23    $69.00
#
# [79 rows x 4 columns]

# %%
# define filename for data
output_path = 'cheebas.csv'

# overwrite previous file with new file containing previous and new data
joined_data.to_csv(output_path, index = False)
